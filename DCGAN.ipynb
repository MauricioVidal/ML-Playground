# %%
# Access files from your Google Drive
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# !ls '/content/gdrive/My Drive/Colab Notebooks'
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: Transport endpoint is not connected
#  CNN_FashionMNIST.ipynb   g_model.h5   'Tweet Sentiment Extraction.ipynb'
#  DCGAN.ipynb		  pokemon.csv
#  gan_images		  pokemon.pkl

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Conv2D, Flatten, BatchNormalization
from tensorflow.keras.layers import Reshape, Conv2DTranspose, LeakyReLU, Dropout

from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD, Adam

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle
import os

# %%
os.chdir('/content/gdrive/My Drive/Colab Notebooks/')
with open('pokemon.pkl','rb') as f:
    X = pickle.load(f)

dataset = pd.read_csv('pokemon.csv')
#Only the png images and electric pokemon
img_format = dataset['Name'].apply(lambda x : x.split('.')[1])
X = X[dataset.loc[(img_format == 'png') & (dataset['Type1'] == 'Electric')].index]
Y = np.ones(X.shape[0])
X = X / 255. * 2 -1
print("x_train.shape: ", X.shape)

plt.imshow((X[1]+1)*0.5)
# Out:
# x_train.shape:  (36, 120, 120, 3)

# %%
dataset['Type1'].unique()
# Out:
# array(['Water', 'Psychic', 'Ghost', 'Rock', 'Fire', 'Normal', 'Electric',
#        'Ice', 'Ground', 'Bug', 'Dark', 'Dragon', 'Poison', 'Fighting',
#        'Grass', 'Steel', 'Fairy', 'Flying'], dtype=object)

# %%
N, H, W, C = X.shape
D = H*W*C

# %%
def build_generator():
  i = Input(shape = (100, ))
  
  x = Dense(15*15*256)(i)
  x = BatchNormalization()(x)
  x = LeakyReLU()(x)

  x = Reshape((15, 15, 256))(x)
  #(15, 15, 256)

  x = Conv2DTranspose(128, (5,5), strides=(1,1), padding='same')(x)
  x = BatchNormalization()(x)
  x = LeakyReLU()(x)
  #(15, 15, 128)

  x = Conv2DTranspose(64, (5,5), strides=(2,2), padding='same')(x)
  x = BatchNormalization()(x)
  x = LeakyReLU()(x)
  #(30, 30, 64)

  x = Conv2DTranspose(32, (5,5), strides=(2,2), padding='same')(x)
  x = BatchNormalization()(x)
  x = LeakyReLU()(x)
  #(60, 60, 64)

  x = Conv2DTranspose(3, (5,5), strides=(2,2), padding='same')(x)
  #(120, 120, 3)

  '''x = tf.subtract(x, tf.reduce_min(x))
  x = tf.divide(x, tf.reduce_max(x));
  x = tf.multiply(x, tf.constant(2.))
  x = tf.subtract(x, tf.constant(1.))'''
  
  model = Model(i, x)
  return model

# %%
def build_discriminator():
  i = Input(shape = (H, W, C))

  x = Conv2D(64, (5, 5), strides=(2,2), padding='same')(i)
  x = LeakyReLU()(x)
  x = Dropout(0.3)(x)

  x = Conv2D(128, (5, 5), strides=(2,2), padding='same')(x)
  x = LeakyReLU()(x)
  x = Dropout(0.3)(x)

  x = Flatten()(x)
  x = Dense(1, activation='sigmoid')(x)

  model = Model(i, x)
  return model

# %%
discriminator  = build_discriminator()
discriminator.compile(
    loss = 'binary_crossentropy',
    optimizer = Adam(2e-4, 0.5),
    metrics=['accuracy']
)

generator = build_generator()

z = Input(shape = (100, ))

img = generator(z)

discriminator.trainable = False

fake_pred = discriminator(img)

combined_model = Model(z, fake_pred)

combined_model.compile(
    loss = 'binary_crossentropy',
    optimizer=Adam(2e-4, 0.5)
    )

# %%
batch_size = 20
epochs = 10000
sample_period = 200

ones = np.ones(batch_size)
zeros = np.zeros(batch_size)

d_losses = []
g_losses = []

if not os.path.exists('gan_images'):
  os.makedirs('gan_images')

# %%
def sample_images(epoch):
  rows, cols = 3, 3
  noise = np.random.randn(rows*cols, 100)
  imgs = generator.predict(noise)
  imgs = imgs - imgs.min()
  imgs = imgs / imgs.max()
  fig, axs = plt.subplots(rows, cols)
  idx = 0
  for i in range(rows):
    for j in range(cols):
      axs[i,j].imshow(imgs[idx])
      axs[i,j].axis('off')
      idx += 1
  
  #plt.show()
  fig.savefig("gan_images/%d.png"%epoch)
  generator.save('g_model.h5')
  plt.close()

# %%
for epoch in range(epochs):
  idx = np.random.randint(0, X.shape[0], batch_size)
  real_imgs = X[idx]
  
  noise = np.random.randn(batch_size, 100)
  fake_imgs = generator.predict(noise)

  #data_generator = tf.keras.preprocessing.image.ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)
  #train_generator = data_generator.flow(real_imgs, Y, batch_size)

  d_loss_real, d_acc_real = discriminator.train_on_batch(real_imgs, ones)
  d_loss_fake, d_acc_fake = discriminator.train_on_batch(fake_imgs, zeros)

  d_loss = 0.5 * (d_loss_real + d_loss_fake)
  d_acc = 0.5 * (d_acc_real + d_acc_fake)

  noise = np.random.randn(batch_size, 100)
  g_loss = combined_model.train_on_batch(noise, ones)

  noise = np.random.randn(batch_size, 100)
  g_loss = combined_model.train_on_batch(noise, ones)

  noise = np.random.randn(batch_size, 100)
  g_loss = combined_model.train_on_batch(noise, ones)

  d_losses.append(d_loss)
  g_losses.append(g_loss)

  if epoch % 100 == 0:
    print(f"epoch: {epoch+1}/{epochs}, d_loss: {d_loss:.2f} - d_acc: {d_acc:.2f}\
    g_loss: {g_loss:.2f}")

  if epoch % sample_period == 0:
    sample_images(epoch)
# Out:
# epoch: 1/10000, d_loss: 0.69 - d_acc: 0.20    g_loss: 0.33
# epoch: 101/10000, d_loss: 0.00 - d_acc: 1.00    g_loss: 0.00
# epoch: 201/10000, d_loss: 0.93 - d_acc: 0.08    g_loss: 0.55
# epoch: 301/10000, d_loss: 0.72 - d_acc: 0.47    g_loss: 0.18
# epoch: 401/10000, d_loss: 0.78 - d_acc: 0.22    g_loss: 0.54
# epoch: 501/10000, d_loss: 0.74 - d_acc: 0.38    g_loss: 0.77
# epoch: 601/10000, d_loss: 0.73 - d_acc: 0.40    g_loss: 0.77
# epoch: 701/10000, d_loss: 0.70 - d_acc: 0.42    g_loss: 0.76
# epoch: 801/10000, d_loss: 0.67 - d_acc: 0.47    g_loss: 0.75
# epoch: 901/10000, d_loss: 0.64 - d_acc: 0.80    g_loss: 0.75
# epoch: 1001/10000, d_loss: 0.65 - d_acc: 0.70    g_loss: 0.99
# epoch: 1101/10000, d_loss: 0.62 - d_acc: 0.80    g_loss: 0.87
# epoch: 1201/10000, d_loss: 0.57 - d_acc: 0.78    g_loss: 0.95
# epoch: 1301/10000, d_loss: 0.57 - d_acc: 0.77    g_loss: 1.08
# epoch: 1401/10000, d_loss: 0.53 - d_acc: 0.88    g_loss: 0.99
# epoch: 1501/10000, d_loss: 0.58 - d_acc: 0.78    g_loss: 1.02
# epoch: 1601/10000, d_loss: 0.51 - d_acc: 0.82    g_loss: 0.83
# epoch: 1701/10000, d_loss: 0.39 - d_acc: 1.00    g_loss: 1.52
# epoch: 1801/10000, d_loss: 0.58 - d_acc: 0.75    g_loss: 1.43
# epoch: 1901/10000, d_loss: 0.39 - d_acc: 0.95    g_loss: 1.49
# epoch: 2001/10000, d_loss: 0.15 - d_acc: 1.00    g_loss: 0.11
# epoch: 2101/10000, d_loss: 0.35 - d_acc: 0.97    g_loss: 0.75
# epoch: 2201/10000, d_loss: 0.37 - d_acc: 0.90    g_loss: 1.68
# epoch: 2301/10000, d_loss: 0.38 - d_acc: 0.93    g_loss: 1.52
# epoch: 2401/10000, d_loss: 0.30 - d_acc: 0.97    g_loss: 1.73
# epoch: 2501/10000, d_loss: 0.25 - d_acc: 0.92    g_loss: 1.72
# epoch: 2601/10000, d_loss: 0.24 - d_acc: 0.93    g_loss: 1.98
# epoch: 2701/10000, d_loss: 0.25 - d_acc: 1.00    g_loss: 1.71
# epoch: 2801/10000, d_loss: 0.40 - d_acc: 0.85    g_loss: 1.92
# epoch: 2901/10000, d_loss: 0.30 - d_acc: 0.90    g_loss: 2.05
# epoch: 3001/10000, d_loss: 0.24 - d_acc: 0.92    g_loss: 2.22
# epoch: 3101/10000, d_loss: 0.68 - d_acc: 0.68    g_loss: 3.80
# epoch: 3201/10000, d_loss: 0.27 - d_acc: 0.92    g_loss: 2.61
# epoch: 3301/10000, d_loss: 0.14 - d_acc: 0.97    g_loss: 2.82
# epoch: 3401/10000, d_loss: 0.13 - d_acc: 1.00    g_loss: 0.24
# epoch: 3501/10000, d_loss: 0.57 - d_acc: 0.62    g_loss: 1.70
# epoch: 3601/10000, d_loss: 0.23 - d_acc: 0.95    g_loss: 1.99
# epoch: 3701/10000, d_loss: 0.23 - d_acc: 0.97    g_loss: 2.13
# epoch: 3801/10000, d_loss: 0.15 - d_acc: 0.95    g_loss: 2.16
# epoch: 3901/10000, d_loss: 0.20 - d_acc: 0.95    g_loss: 3.74
# epoch: 4001/10000, d_loss: 0.18 - d_acc: 0.95    g_loss: 2.76
# epoch: 4101/10000, d_loss: 0.17 - d_acc: 0.93    g_loss: 2.72
# epoch: 4201/10000, d_loss: 0.13 - d_acc: 0.97    g_loss: 2.87
# epoch: 4301/10000, d_loss: 0.11 - d_acc: 0.97    g_loss: 2.54
# epoch: 4401/10000, d_loss: 0.25 - d_acc: 0.90    g_loss: 2.39
# epoch: 4501/10000, d_loss: 0.13 - d_acc: 0.95    g_loss: 3.28
# epoch: 4601/10000, d_loss: 0.08 - d_acc: 1.00    g_loss: 2.59
# epoch: 4701/10000, d_loss: 0.19 - d_acc: 0.93    g_loss: 3.24
# epoch: 4801/10000, d_loss: 0.10 - d_acc: 0.97    g_loss: 3.19
# epoch: 4901/10000, d_loss: 0.13 - d_acc: 0.97    g_loss: 3.57
# epoch: 5001/10000, d_loss: 0.43 - d_acc: 0.88    g_loss: 3.76
# epoch: 5101/10000, d_loss: 0.29 - d_acc: 0.97    g_loss: 3.02
# epoch: 5201/10000, d_loss: 0.06 - d_acc: 1.00    g_loss: 3.60
# epoch: 5301/10000, d_loss: 0.12 - d_acc: 1.00    g_loss: 3.06
# epoch: 5401/10000, d_loss: 0.15 - d_acc: 0.97    g_loss: 3.50
# epoch: 5501/10000, d_loss: 0.12 - d_acc: 0.97    g_loss: 3.69
# epoch: 5601/10000, d_loss: 0.15 - d_acc: 0.97    g_loss: 3.71
# epoch: 5701/10000, d_loss: 0.07 - d_acc: 1.00    g_loss: 3.65
# epoch: 5801/10000, d_loss: 0.12 - d_acc: 0.97    g_loss: 2.60
# epoch: 5901/10000, d_loss: 0.49 - d_acc: 0.75    g_loss: 4.11
# epoch: 6001/10000, d_loss: 0.19 - d_acc: 0.95    g_loss: 3.01
# epoch: 6101/10000, d_loss: 0.19 - d_acc: 0.95    g_loss: 2.72
# epoch: 6201/10000, d_loss: 0.47 - d_acc: 0.93    g_loss: 2.06
# epoch: 6301/10000, d_loss: 0.11 - d_acc: 0.95    g_loss: 3.42
# epoch: 6401/10000, d_loss: 0.27 - d_acc: 0.92    g_loss: 3.62
# epoch: 6501/10000, d_loss: 0.26 - d_acc: 0.90    g_loss: 2.51
# epoch: 6601/10000, d_loss: 0.08 - d_acc: 0.97    g_loss: 3.73
# epoch: 6701/10000, d_loss: 0.04 - d_acc: 1.00    g_loss: 4.21
# epoch: 6801/10000, d_loss: 0.36 - d_acc: 0.85    g_loss: 1.91
# epoch: 6901/10000, d_loss: 0.42 - d_acc: 0.90    g_loss: 3.06
# epoch: 7001/10000, d_loss: 2.23 - d_acc: 0.37    g_loss: 2.36
# epoch: 7101/10000, d_loss: 0.08 - d_acc: 1.00    g_loss: 3.46
# epoch: 7201/10000, d_loss: 0.63 - d_acc: 0.70    g_loss: 1.91
# epoch: 7301/10000, d_loss: 0.34 - d_acc: 0.85    g_loss: 3.69
# epoch: 7401/10000, d_loss: 0.42 - d_acc: 0.80    g_loss: 2.53
# epoch: 7501/10000, d_loss: 0.26 - d_acc: 0.90    g_loss: 2.91
# epoch: 7601/10000, d_loss: 0.16 - d_acc: 0.95    g_loss: 3.09
# epoch: 7701/10000, d_loss: 0.17 - d_acc: 0.95    g_loss: 3.51
# epoch: 7801/10000, d_loss: 0.03 - d_acc: 1.00    g_loss: 4.41
# epoch: 7901/10000, d_loss: 0.27 - d_acc: 0.90    g_loss: 2.89
# epoch: 8001/10000, d_loss: 0.11 - d_acc: 0.97    g_loss: 3.40
# epoch: 8101/10000, d_loss: 0.04 - d_acc: 1.00    g_loss: 4.41
# epoch: 8201/10000, d_loss: 0.42 - d_acc: 0.95    g_loss: 0.25
# epoch: 8301/10000, d_loss: 0.13 - d_acc: 0.92    g_loss: 2.74
# epoch: 8401/10000, d_loss: 0.33 - d_acc: 0.88    g_loss: 3.55
# epoch: 8501/10000, d_loss: 0.22 - d_acc: 0.93    g_loss: 3.79
# epoch: 8601/10000, d_loss: 0.09 - d_acc: 0.97    g_loss: 2.92
# epoch: 8701/10000, d_loss: 0.06 - d_acc: 0.97    g_loss: 3.86
# epoch: 8801/10000, d_loss: 0.37 - d_acc: 0.90    g_loss: 3.26
# epoch: 8901/10000, d_loss: 0.01 - d_acc: 1.00    g_loss: 4.49
# epoch: 9001/10000, d_loss: 0.26 - d_acc: 0.95    g_loss: 4.02
# epoch: 9101/10000, d_loss: 0.13 - d_acc: 0.95    g_loss: 4.81
# epoch: 9201/10000, d_loss: 0.17 - d_acc: 0.95    g_loss: 3.50
# epoch: 9301/10000, d_loss: 0.26 - d_acc: 0.95    g_loss: 3.13
# epoch: 9401/10000, d_loss: 0.12 - d_acc: 0.97    g_loss: 3.81
# epoch: 9501/10000, d_loss: 0.12 - d_acc: 0.97    g_loss: 3.67
# epoch: 9601/10000, d_loss: 0.55 - d_acc: 0.82    g_loss: 3.69
# epoch: 9701/10000, d_loss: 0.49 - d_acc: 0.88    g_loss: 3.02
# epoch: 9801/10000, d_loss: 0.45 - d_acc: 0.85    g_loss: 3.52
# epoch: 9901/10000, d_loss: 0.43 - d_acc: 0.90    g_loss: 2.20

# %%
plt.plot(g_losses, label='g_losses')
plt.plot(d_losses, label='d_losses')
plt.legend()

# %%
from skimage.io import imread
for epoch in range(0,epochs+1000, 1000):
  a = imread('gan_image/%d.png'%epoch)
  plt.imshow(a)
  plt.show()
